# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt


df= pd.read_csv("G:/My Drive/coursera/data Science/plotting and charting of data/assignment4/Religion_in_the_United_States_1.csv")
df
# Out:
#          Religious Affiliation  National %  National %.1  South %  West %  \
# 0                    Christian        69.7          69.7       74      65
# 1                   Protestant        45.6          45.6       53      36
# 2            White Evangelical        14.5          14.5       18      10
# 3    White Mainline Protestant        16.4          16.4       17      14
# 4             Black Protestant         7.3           7.3       10       3
# 5          Hispanic Protestant         3.9           3.9        4       5
# 6   Other non-white Protestant         3.5           3.5        4       4
# 7                     Catholic        21.8          21.8       19      24
# 8               White Catholic        11.7          11.7        9       9
# 9            Hispanic Catholic         8.2           8.2        8      13
# 10    Other non-white Catholic         1.9           1.9        2       2
# 11                      Mormon         1.3           1.3        1       4
# ...

# %%
df = df.iloc[:-1 , :]
df
# Out:
#          Religious Affiliation  National %  National %.1  South %  West %  \
# 0                    Christian        69.7          69.7       74      65
# 1                   Protestant        45.6          45.6       53      36
# 2            White Evangelical        14.5          14.5       18      10
# 3    White Mainline Protestant        16.4          16.4       17      14
# 4             Black Protestant         7.3           7.3       10       3
# 5          Hispanic Protestant         3.9           3.9        4       5
# 6   Other non-white Protestant         3.5           3.5        4       4
# 7                     Catholic        21.8          21.8       19      24
# 8               White Catholic        11.7          11.7        9       9
# 9            Hispanic Catholic         8.2           8.2        8      13
# 10    Other non-white Catholic         1.9           1.9        2       2
# 11                      Mormon         1.3           1.3        1       4
# ...

# %%
df1=df.drop(df.columns[[2]], axis=1, inplace=True)
df
# Out:
# c:\users\maniv\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          Religious Affiliation  National %  West %  Midwest %  Northeast %
# 0                    Christian        69.7      65         72           67
# 1                   Protestant        45.6      36         50           39
# 2            White Evangelical        14.5      10         18            9
# 3    White Mainline Protestant        16.4      14         21           15
# 4             Black Protestant         7.3       3          6            8
# 5          Hispanic Protestant         3.9       5          2            4
# 6   Other non-white Protestant         3.5       4          3            3
# ...

# %%
x=df['Religious Affiliation'];
x
# Out:
# 0                      Christian
# 1                     Protestant
# 2              White Evangelical
# 3      White Mainline Protestant
# 4               Black Protestant
# 5            Hispanic Protestant
# 6     Other non-white Protestant
# 7                       Catholic
# 8                 White Catholic
# 9              Hispanic Catholic
# 10      Other non-white Catholic
# 11                        Mormon
# 12             Jehovah's Witness
# 13            Orthodox Christian
# 14                  Unaffiliated
# 15                 Non-Christian
# 16                        Jewish
# 17                        Muslim
# 18                      Buddhist
# 19                         Hindu
# 20           Other non-Christian
# Name: Religious Affiliation, dtype: object

# %%
y = df.iloc[:, 1:6]
y
# Out:
#     National %  West %  Midwest %  Northeast %
# 0         69.7      65         72           67
# 1         45.6      36         50           39
# 2         14.5      10         18            9
# 3         16.4      14         21           15
# 4          7.3       3          6            8
# 5          3.9       5          2            4
# 6          3.5       4          3            3
# 7         21.8      24         21           26
# 8         11.7       9         15           16
# 9          8.2      13          4            8
# 10         1.9       2          2            2
# 11         1.3       4          1            1
# 12         0.5       1          0            0
# 13         0.5       0          0            1
# 14        23.3      27         22           24
# 15         7.0       8          6            9
# 16         1.4       1          1            3
# 17         0.8       1          1            1
# 18         0.8       1          1            1
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(x,y,linestyle='-',linewidth=2,markersize=10)
plt.xticks(rotation=45)
plt.xlabel("Religion",color='green',fontsize=20)
plt.ylabel("% Population",color='green',fontsize=20)
plt.legend(['National %','West %','Midwest %','Northeast %'], loc =1,fontsize=20)
plt.title('Religious Population in Region',fontsize=20)
plt.show()
